# %%
import asyncio
import logging
import re

try:
    import uvloop
    asyncio.set_event_loop_policy(uvloop.EventLoopPolicy())
except ImportError:
    pass

import cProfile
import pstats
from functools import wraps
from io import StringIO

import aiohttp
import orjson
from cachetools import TTLCache
from lxml import etree

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

resolver = aiohttp.resolver.AsyncResolver(nameservers=["8.8.8.8", "8.8.4.4"])
conn = aiohttp.TCPConnector(ssl=False, limit=100, resolver=resolver)

PROXY = "http://swed:Artiffu$i0nSwed587@193.188.21.11:7357"
SUBTITLE_REGEX = re.compile(
    r'<text start="([\d.]+)" dur="([\d.]+)".*?>(.*?)</text>', re.DOTALL
)
JSON_REGEX = re.compile(r"ytInitialPlayerResponse\s*=\s*({.+?});", re.DOTALL)

subtitle_cache = TTLCache(maxsize=1000, ttl=3600)

def async_profiler(func):
    @wraps(func)
    async def wrapper(*args, **kwargs):
        pr = cProfile.Profile()
        pr.enable()
        result = await func(*args, **kwargs)
        pr.disable()
        s = StringIO()
        ps = pstats.Stats(pr, stream=s).sort_stats('cumulative')
        ps.print_stats()
        logger.info(f"Профиль для {func.__name__}:\n{s.getvalue()}")
        return result
    return wrapper

# %%
@async_profiler
async def create_session():
    return aiohttp.ClientSession(
        connector=conn,
        trust_env=True,
        timeout=aiohttp.ClientTimeout(
            total=10, connect=5, sock_connect=5, sock_read=5
        ),
    )


@async_profiler
async def fetch(session, url):
    try:
        async with session.get(url, proxy=PROXY) as response:
            return await response.text()
    except Exception as e:
        logger.error(f"Ошибка при запросе {url}: {str(e)}")
        return None


@async_profiler
async def extract_json_and_subtitle_url(html_content):
    start = html_content.find("ytInitialPlayerResponse = ") + 26
    end = html_content.find("};", start) + 1
    if start > 25 and end > 0:
        try:
            json_data = orjson.loads(html_content[start:end])
            captions = (
                json_data.get("captions", {})
                .get("playerCaptionsTracklistRenderer", {})
                .get("captionTracks", [])
            )
            for caption in captions:
                if caption.get("languageCode") == "ru":
                    return caption.get("baseUrl")
        except orjson.JSONDecodeError as e:
            logger.error(f"Ошибка при парсинге JSON: {str(e)}")
    return None


@async_profiler
async def parse_subtitles(xml_content):
    if not xml_content:
        return []
    root = etree.fromstring(xml_content.encode("utf-8"))
    return [
        {
            "start": float(text.get("start")),
            "duration": float(text.get("dur")),
            "text": text.text.strip()
            .replace("&amp;", "&")
            .replace("&lt;", "<")
            .replace("&gt;", ">"),
        }
        for text in root.findall(".//text")
    ]


@async_profiler
async def get_russian_subtitles(video_id):
    try:
        async with await create_session() as session:
            url = f"https://www.youtube.com/watch?v={video_id}"
            html_content = await fetch(session, url)
            if not html_content:
                return None, False

            subtitle_url = await extract_json_and_subtitle_url(html_content)
            if not subtitle_url:
                return None, False

            xml_content, is_auto_generated = await asyncio.gather(
                fetch(session, subtitle_url),
                asyncio.to_thread(lambda: "kind=asr" in subtitle_url),
            )

            subtitles = await parse_subtitles(xml_content)
            return subtitles, is_auto_generated

    except Exception as e:
        logger.error(
            f"Неожиданная ошибка при обработке видео {video_id}: {str(e)}"
        )

    return None, False

# %%
subtitles, is_auto_generated = await get_russian_subtitles("Ajy1lS9qJbs")

f"Автоматически сгенерированы: {is_auto_generated}" if subtitles else "Не удалось получить субтитры для видео"
# Out:
# 2024-08-14 14:23:47,247 - ERROR - Неожиданная ошибка при обработке видео Ajy1lS9qJbs: Another profiling tool is already active
# 2024-08-14 14:23:47,256 - INFO - Профиль для get_russian_subtitles:
#          812 function calls (787 primitive calls) in 0.002 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.001    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/base_events.py:1909(_run_once)
#         1    0.000    0.000    0.001    0.001 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/events.py:86(_run)
#         1    0.000    0.000    0.001    0.001 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.001    0.001 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/tornado/ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.001    0.001 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:694(<lambda>)
#         1    0.000    0.000    0.001    0.001 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:583(_handle_events)
#         1    0.000    0.000    0.001    0.001 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:624(_handle_recv)
#         1    0.000    0.000    0.001    0.001 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:556(_run_callback)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:157(_handle_event)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:616(_flush)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:663(_rebuild_io_state)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:754(send)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:278(_really_send)
#       2/1    0.000    0.000    0.000    0.000 /tmp/ipykernel_148511/1627239315.py:60(get_russian_subtitles)
#       2/1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1558(error)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/sugar/socket.py:703(send_multipart)
#       2/1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1660(_log)
#       2/1    0.001    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1686(handle)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1746(callHandlers)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:690(serialize)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1011(handle)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:259(schedule)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:686(_update_handler)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1148(emit)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:655(write)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:92(json_packer)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1137(flush)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:43(__getattr__)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/json/__init__.py:183(dumps)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:592(flush)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/sugar/socket.py:778(recv_multipart)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:587(_schedule_in_thread)
#      15/3    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/sugar/socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/tornado/ioloop.py:596(call_later)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/json/encoder.py:183(encode)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/tornado/platform/asyncio.py:210(call_at)
#        11    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/enum.py:1551(__or__)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/base_events.py:743(call_later)
#   132/128    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/decorator.py:199(fix)
#       2/1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:637(wait)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/selectors.py:451(select)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/json/encoder.py:205(iterencode)
#         6    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/enum.py:1562(__and__)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/base_events.py:767(call_at)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:988(format)
#        51    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/enum.py:1544(_get_value)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:690(format)
#         2    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1645(makeRecord)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:66(_get_attr_opt)
#       2/1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:323(wait)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:298(__init__)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:649(msg)
#        23    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/enum.py:726(__call__)
#        19    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/traitlets/traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:3268(bind)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:675(sign)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/tornado/platform/asyncio.py:225(add_callback)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/typing.py:1221(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:542(sending)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:710(_flush_buffers)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:3129(_bind)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:616(set)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/typing.py:1492(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:271(send_multipart)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:622(formatTime)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:645(msg_header)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/traitlets/traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/jsonutil.py:107(json_default)
#         6    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/typing.py:392(inner)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/base_events.py:785(call_soon)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/traitlets/traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:424(notify_all)
#         5    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:1222(is_alive)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1790(isEnabledFor)
#        19    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/traitlets/traitlets.py:629(get)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/traitlets/traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1611(findCaller)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/base_events.py:814(_call_soon)
#        23    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/enum.py:1129(__new__)
#         3    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/events.py:36(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/hmac.py:122(copy)
#      11/8    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_148511/1899640167.py:38(wrapper)
#         2    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:272(msg_header)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:588(__init__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/queue.py:97(empty)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/events.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method time.localtime}
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:2945(apply_defaults)
#         5    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:1155(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/typing.py:1285(__hash__)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/hmac.py:161(hexdigest)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:668(usesTime)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:600(msg_id)
#         1    0.000    0.000    0.000    0.000 <frozen posixpath>:169(basename)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:505(parent_header)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:718(_rotate_buffers)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:674(formatMessage)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/hmac.py:117(update)
#         1    0.000    0.000    0.000    0.000 {built-in method time.strftime}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:216(_check_mp_mode)
#         3    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:200(_is_internal_frame)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/traitlets/traitlets.py:2635(validate)
#         7    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:198(utcnow)
#         3    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:299(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen posixpath>:117(splitext)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:2892(args)
#         3    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/base_events.py:734(time)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:462(format)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        43    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/typing.py:2182(cast)
#        19    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/traitlets/traitlets.py:727(_cross_validate)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:277(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:968(acquire)
#         1    0.000    0.000    0.000    0.000 {method 'enable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:447(usesTime)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:234(_acquireLock)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:627(clear)
#         4    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:725(_hooks)
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:455(_format)
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:975(release)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:129(getLevelName)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/session.py:281(extract_header)
#         7    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:2915(kwargs)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:170(<lambda>)
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 <frozen posixpath>:52(normcase)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/queue.py:209(_qsize)
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:243(_releaseLock)
#         1    0.000    0.000    0.000    0.000 <frozen genericpath>:133(_splitext)
#         3    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/tornado/ioloop.py:541(time)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:1485(current_thread)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/jupyter_client/jsonutil.py:38(_ensure_tzinfo)
#         1    0.000    0.000    0.000    0.000 <frozen posixpath>:41(_get_sep)
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:314(_is_owned)
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/json/encoder.py:105(__init__)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:550(_is_master_process)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/events.py:127(__lt__)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1776(getEffectiveLevel)
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:383(getMessage)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:308(_release_save)
#         3    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:538(receiving)
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/dateutil/tz/tz.py:74(utcoffset)
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         1    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get_name' of '_asyncio.Task' objects}
#        10    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:2804(kind)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/traitlets/traitlets.py:2558(_validate_bounds)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:831(filter)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:1182(name)
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         5    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:601(is_set)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/threading.py:1198(ident)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:3085(parameters)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         3    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/base_events.py:539(_check_closed)
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/site-packages/ipykernel/iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.current_task}
#         1    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/selector_events.py:750(_process_events)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x5608d1aa5f60}
#         3    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/asyncio/base_events.py:2004(get_debug)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/logging/__init__.py:1369(disable)
#         1    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         4    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:2792(name)
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/inspect.py:2884(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 /home/michael/github/youtube/.micromamba/envs/default/lib/python3.12/hmac.py:139(_current)
# 'Не удалось получить субтитры для видео'
